# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
Covid_Deaths = pd.read_csv('COVID DEATHS.csv')

# %%
Covid_Deaths.isnull()
# Out:
#         iso_code  continent  location   date  population  total_cases  \
# 0          False      False     False  False       False         True
# 1          False      False     False  False       False         True
# 2          False      False     False  False       False         True
# 3          False      False     False  False       False         True
# 4          False      False     False  False       False         True
# ...          ...        ...       ...    ...         ...          ...
# 302744     False      False     False  False       False        False
# 302745     False      False     False  False       False        False
# 302746     False      False     False  False       False        False
# 302747     False      False     False  False       False        False
# 302748     False      False     False  False       False        False
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# ...

# %%
Missing_Rows = Covid_Deaths.isnull().any(axis = 1)
Covid_Deaths[Missing_Rows]
# Out:
#        iso_code continent     location       date  population  total_cases  \
# 0           AFG      Asia  Afghanistan   1/3/2020    41128772          NaN
# 1           AFG      Asia  Afghanistan   1/4/2020    41128772          NaN
# 2           AFG      Asia  Afghanistan   1/5/2020    41128772          NaN
# 3           AFG      Asia  Afghanistan   1/6/2020    41128772          NaN
# 4           AFG      Asia  Afghanistan   1/7/2020    41128772          NaN
# ...         ...       ...          ...        ...         ...          ...
# 302744      ZWE    Africa     Zimbabwe   4/8/2023    16320539     264578.0
# 302745      ZWE    Africa     Zimbabwe   4/9/2023    16320539     264582.0
# 302746      ZWE    Africa     Zimbabwe  4/10/2023    16320539     264584.0
# 302747      ZWE    Africa     Zimbabwe  4/11/2023    16320539     264584.0
# 302748      ZWE    Africa     Zimbabwe  4/12/2023    16320539     264584.0
#
# ...

# %%
Covid_Death_Clear_Row = Covid_Deaths.drop(columns = ['new_cases_smoothed' ,	'total_deaths' , 'new_deaths_smoothed' , 'total_cases_per_million' ,
'reproduction_rate' ,	'icu_patients' , 'icu_patients_per_million' ,	'hosp_patients' ,	'hosp_patients_per_million' ,	'weekly_icu_admissions' ,	'weekly_icu_admissions_per_million' ,	'weekly_hosp_admissions' ,	'weekly_hosp_admissions_per_million'])

# %%
Covid_Death_Clear_Row
# Out:
#        iso_code continent     location       date  population  total_cases  \
# 0           AFG      Asia  Afghanistan   1/3/2020    41128772          NaN
# 1           AFG      Asia  Afghanistan   1/4/2020    41128772          NaN
# 2           AFG      Asia  Afghanistan   1/5/2020    41128772          NaN
# 3           AFG      Asia  Afghanistan   1/6/2020    41128772          NaN
# 4           AFG      Asia  Afghanistan   1/7/2020    41128772          NaN
# ...         ...       ...          ...        ...         ...          ...
# 302744      ZWE    Africa     Zimbabwe   4/8/2023    16320539     264578.0
# 302745      ZWE    Africa     Zimbabwe   4/9/2023    16320539     264582.0
# 302746      ZWE    Africa     Zimbabwe  4/10/2023    16320539     264584.0
# 302747      ZWE    Africa     Zimbabwe  4/11/2023    16320539     264584.0
# 302748      ZWE    Africa     Zimbabwe  4/12/2023    16320539     264584.0
#
#         new_cases  new_deaths  new_cases_per_million  \
# ...

# %%
Covid_Death_Clear_Row['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
Covid_Death_Clear_Row['total_cases']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 302744    264578.0
# 302745    264582.0
# 302746    264584.0
# 302747    264584.0
# 302748    264584.0
# Name: total_cases, Length: 302749, dtype: float64

# %%
Covid_Deaths['continent'] == 'Asia'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 302744    True
# 302745    True
# 302746    True
# 302747    True
# 302748    True
# Name: continent, Length: 302749, dtype: bool

# %%
Covid_Deathss = Covid_Deaths.loc[Covid_Deaths['continent'] == 'Asia']

# %%
Covid_Deathss
# Out:
#        iso_code continent     location       date  population  total_cases  \
# 0           AFG      Asia  Afghanistan   1/3/2020    41128772          NaN
# 1           AFG      Asia  Afghanistan   1/4/2020    41128772          NaN
# 2           AFG      Asia  Afghanistan   1/5/2020    41128772          NaN
# 3           AFG      Asia  Afghanistan   1/6/2020    41128772          NaN
# 4           AFG      Asia  Afghanistan   1/7/2020    41128772          NaN
# ...         ...       ...          ...        ...         ...          ...
# 302744      ZWE      Asia     Zimbabwe   4/8/2023    16320539     264578.0
# 302745      ZWE      Asia     Zimbabwe   4/9/2023    16320539     264582.0
# 302746      ZWE      Asia     Zimbabwe  4/10/2023    16320539     264584.0
# 302747      ZWE      Asia     Zimbabwe  4/11/2023    16320539     264584.0
# 302748      ZWE      Asia     Zimbabwe  4/12/2023    16320539     264584.0
#
# ...

# %%
Covid_Deathsss = Covid_Deaths.sort_values('total_cases' , ascending = False)

# %%
Covid_Deathsss
# Out:
#         iso_code continent  location       date  population  total_cases  \
# 299154  OWID_WRL      Asia     World  4/11/2023  7975105024  762790388.0
# 299155  OWID_WRL      Asia     World  4/12/2023  7975105024  762790388.0
# 299153  OWID_WRL      Asia     World  4/10/2023  7975105024  762773745.0
# 299152  OWID_WRL      Asia     World   4/9/2023  7975105024  762739136.0
# 299151  OWID_WRL      Asia     World   4/8/2023  7975105024  762609674.0
# ...          ...       ...       ...        ...         ...          ...
# 301626       ZWE      Asia  Zimbabwe  3/16/2020    16320539          NaN
# 301627       ZWE      Asia  Zimbabwe  3/17/2020    16320539          NaN
# 301628       ZWE      Asia  Zimbabwe  3/18/2020    16320539          NaN
# 301629       ZWE      Asia  Zimbabwe  3/19/2020    16320539          NaN
# 301630       ZWE      Asia  Zimbabwe  3/20/2020    16320539          NaN
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# ...

# %%
Covid_Deathsss.iloc[0:10]
# Out:
#         iso_code continent location       date  population  total_cases  \
# 299154  OWID_WRL      Asia    World  4/11/2023  7975105024  762790388.0
# 299155  OWID_WRL      Asia    World  4/12/2023  7975105024  762790388.0
# 299153  OWID_WRL      Asia    World  4/10/2023  7975105024  762773745.0
# 299152  OWID_WRL      Asia    World   4/9/2023  7975105024  762739136.0
# 299151  OWID_WRL      Asia    World   4/8/2023  7975105024  762609674.0
# 299150  OWID_WRL      Asia    World   4/7/2023  7975105024  762559025.0
# 299149  OWID_WRL      Asia    World   4/6/2023  7975105024  762501634.0
# 299148  OWID_WRL      Asia    World   4/5/2023  7975105024  762435438.0
# 299147  OWID_WRL      Asia    World   4/4/2023  7975105024  762363634.0
# 299146  OWID_WRL      Asia    World   4/3/2023  7975105024  762299608.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 299154    16643.0           60964.857     6897012.0        94.0  ...
# ...

# %%
sn.countplot(x = 'continent' , data = Covid_Deathsss)
plt.show()
